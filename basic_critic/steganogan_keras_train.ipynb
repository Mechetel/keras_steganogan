# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy

from models import (
  steganogan_encoder_basic_model,
  steganogan_decoder_basic_model,
  steganogan_critic_model
)
from keras_steganogan_critic import KerasSteganoGAN
# Out:
# 2024-08-20 22:58:29.526857: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 2
BATCH_SIZE = 4
MODEL_PATH = '../pretrained_models/steganoGAN_basic_critic.keras'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

def normalize_img(img):
    return (img / 127.5) - 1

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

def create_message_tensor_for_training(batch_size, width, height, data_depth):
    message = tf.random.uniform([batch_size, width, height, data_depth], 0, 2, dtype=tf.int32)
    message = tf.cast(message, tf.float32)
    return message

def create_message_dataset(batch_size, num_batches, width, height, data_depth):
    message_tensors = [create_message_tensor_for_training(batch_size, width, height, data_depth) for _ in range(num_batches)]
    return tf.data.Dataset.from_tensor_slices(tf.concat(message_tensors, axis=0)).batch(batch_size)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=10, validation_data=val_ds)
steganoGAN.save(MODEL_PATH)
# Out:
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 216s 1s/step - bpp: 2.0000 - critic_loss: -0.0019 - decoding_loss: 0.7423 - encoder_decoder_total_loss: 1.0524 - psnr: 5.7563 - realism_loss: 8.8654e-04 - similarity_loss: 0.3092 - ssim: 0.2066 - val_bpp: 2.0000 - val_critic_loss: -0.0077 - val_decoding_loss: 0.6212 - val_encoder_decoder_total_loss: 0.8316 - val_psnr: 7.0459 - val_realism_loss: 0.0018 - val_similarity_loss: 0.2086 - val_ssim: 0.1370
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 208s 1s/step - bpp: 2.0000 - critic_loss: -0.0090 - decoding_loss: 0.5141 - encoder_decoder_total_loss: 0.6222 - psnr: 9.8908 - realism_loss: -1.1113e-04 - similarity_loss: 0.1082 - ssim: 0.3415 - val_bpp: 2.0000 - val_critic_loss: -0.0172 - val_decoding_loss: 0.3114 - val_encoder_decoder_total_loss: 0.4143 - val_psnr: 9.9205 - val_realism_loss: -0.0014 - val_similarity_loss: 0.1043 - val_ssim: 0.2882
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 207s 1s/step - bpp: 2.0000 - critic_loss: -0.0206 - decoding_loss: 0.1814 - encoder_decoder_total_loss: 0.2733 - psnr: 10.4436 - realism_loss: -0.0042 - similarity_loss: 0.0961 - ssim: 0.2802 - val_bpp: 2.0000 - val_critic_loss: -0.0263 - val_decoding_loss: 0.1118 - val_encoder_decoder_total_loss: 0.1618 - val_psnr: 12.1816 - val_realism_loss: -0.0141 - val_similarity_loss: 0.0641 - val_ssim: 0.3806
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - bpp: 2.0000 - critic_loss: -0.0304 - decoding_loss: 0.0707 - encoder_decoder_total_loss: 0.1337 - psnr: 11.3785 - realism_loss: -0.0151 - similarity_loss: 0.0781 - ssim: 0.3167 - val_bpp: 2.0000 - val_critic_loss: -0.0336 - val_decoding_loss: 0.0599 - val_encoder_decoder_total_loss: 0.0933 - val_psnr: 12.9742 - val_realism_loss: -0.0211 - val_similarity_loss: 0.0545 - val_ssim: 0.4207
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - bpp: 2.0000 - critic_loss: -0.0371 - decoding_loss: 0.0488 - encoder_decoder_total_loss: 0.1010 - psnr: 11.6916 - realism_loss: -0.0209 - similarity_loss: 0.0731 - ssim: 0.3476 - val_bpp: 2.0000 - val_critic_loss: -0.0397 - val_decoding_loss: 0.0435 - val_encoder_decoder_total_loss: 0.0703 - val_psnr: 13.4732 - val_realism_loss: -0.0221 - val_similarity_loss: 0.0490 - val_ssim: 0.4517
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - bpp: 2.0000 - critic_loss: -0.0444 - decoding_loss: 0.0406 - encoder_decoder_total_loss: 0.0892 - psnr: 11.9468 - realism_loss: -0.0207 - similarity_loss: 0.0693 - ssim: 0.3744 - val_bpp: 2.0000 - val_critic_loss: -0.0490 - val_decoding_loss: 0.0366 - val_encoder_decoder_total_loss: 0.0651 - val_psnr: 13.7764 - val_realism_loss: -0.0172 - val_similarity_loss: 0.0458 - val_ssim: 0.4767
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - bpp: 2.0000 - critic_loss: -0.0504 - decoding_loss: 0.0362 - encoder_decoder_total_loss: 0.0858 - psnr: 12.2431 - realism_loss: -0.0163 - similarity_loss: 0.0658 - ssim: 0.3958 - val_bpp: 2.0000 - val_critic_loss: -0.0511 - val_decoding_loss: 0.0424 - val_encoder_decoder_total_loss: 0.0711 - val_psnr: 14.1312 - val_realism_loss: -0.0136 - val_similarity_loss: 0.0423 - val_ssim: 0.5145
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 212s 1s/step - bpp: 2.0000 - critic_loss: -0.0536 - decoding_loss: 0.0377 - encoder_decoder_total_loss: 0.0910 - psnr: 12.4261 - realism_loss: -0.0090 - similarity_loss: 0.0622 - ssim: 0.4159 - val_bpp: 2.0000 - val_critic_loss: -0.0595 - val_decoding_loss: 0.0365 - val_encoder_decoder_total_loss: 0.0743 - val_psnr: 14.4462 - val_realism_loss: -0.0013 - val_similarity_loss: 0.0391 - val_ssim: 0.5345
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 217s 1s/step - bpp: 2.0000 - critic_loss: -0.0652 - decoding_loss: 0.0364 - encoder_decoder_total_loss: 0.1013 - psnr: 12.7275 - realism_loss: 0.0061 - similarity_loss: 0.0588 - ssim: 0.4417 - val_bpp: 2.0000 - val_critic_loss: -0.0736 - val_decoding_loss: 0.0301 - val_encoder_decoder_total_loss: 0.0832 - val_psnr: 14.4097 - val_realism_loss: 0.0141 - val_similarity_loss: 0.0390 - val_ssim: 0.5524
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 217s 1s/step - bpp: 2.0000 - critic_loss: -0.0747 - decoding_loss: 0.0375 - encoder_decoder_total_loss: 0.1114 - psnr: 12.6881 - realism_loss: 0.0142 - similarity_loss: 0.0597 - ssim: 0.4456 - val_bpp: 2.0000 - val_critic_loss: -0.0720 - val_decoding_loss: 0.0328 - val_encoder_decoder_total_loss: 0.0864 - val_psnr: 14.6148 - val_realism_loss: 0.0167 - val_similarity_loss: 0.0369 - val_ssim: 0.5669
