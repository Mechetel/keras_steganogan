# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import tensorflow as tf
import numpy as np
from keras.losses import BinaryCrossentropy

from models import (
  steganogan_encoder_basic_model,
  steganogan_encoder_residual_model,
  steganogan_encoder_dense_model,

  steganogan_decoder_basic_model,
  steganogan_decoder_dense_model,
  
  steganogan_critic_model
)
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-07-10 21:51:08.286410: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 2
BATCH_SIZE = 4
MODEL_PATH = 'pretrained_models/steganoGAN_dense.keras'

# %% [markdown]
# ----

# %% [markdown]
# ### Call main encode and decode functions (with creating steganographic image and decoding it)

# %%
steganoGAN = KerasSteganoGAN(image_shape=IMAGE_SHAPE, data_depth=MESSAGE_DEPTH, model_path=MODEL_PATH)
steganoGAN.encode('input.png', 'images/dense/output.png', 'Hello, World!')
steganoGAN.decode('images/dense/output.png')
# Out:
# 'ýÿÿÿÿ^ký\x1a\x00\x02ª\x7fd\x8e\x01\x83õ\x17Xa\x17ÿ¿ßýÿÿù>\x7fÕwýUU]þåíD\x88¹K\x14\x954\t\x11\x83\x15\x18Æ\x00\x04-_WÕWû¿Õ_\x7fß\x80\x05EñA\x11|oy\r÷×¬P+\x80=J\x02ª®ñ}UÀ\x15}Q¾YSQ\x00\x00\x07ÛJ\'3´Á-ZV@`\x80%s«\x03à\x00¡ô\x01\x00\x01]`P%\x97\x1cÜG\x1dZ?\'Õ\x97\x07\x89ÿpªb¬uäÇzªª£ð\x99o\x02X\x9aÞõ\x14ÖÇ}µT\x14¼®ÆÕ\x06×Ó¡Ü\x80¾\x08àjª$.Ö]õQÖÏRßïL^þO?ßw2b\x0e\tf\x96Jd 4(+\x8aj¤/A}µUY¦\x03U\r\x9dé_}W8ósh0\x8dMÚi\x81l4ä_¿ê%&aÝES×Ñ\x04\x95\x19õ\x19\x1díýÁçD\x85Üi&rH\x04ª\x97Ã\x9eÓ[õ´KôOÿÔÈ²÷ \x1d\x03um]\x15tÿ\x95u`°Æ\x88}(1\x01pÿ¼I91EUUUFÝU\x83X-Gõ|´÷×§QäX\x96\x80n$`\x80\x90~X\\1`\x00ÿk¹e#ù\n\x957U5WUWÝÕN\x05\x15°\x80H\x00²§COÕG DïÐ\x1dRà.AtTu\x1d\x15\x15;G÷õQ\x8fýf\x04¡(:".ü?\x1d"]UU`R\x08/h\x8ad×\x94E!ÿÝußßíøD¸8úpÝY\x8acýuÿö?÷Ý\x1dñ\x18\x03U\x15B\x1cUQ]ýVuýýið\x15p\x11qÙvÕUýUAUY~PÙ7¤\x11\x98A\x14W\x16]Á\x95\x91üù\x9b\x83¾\x07\x105\x10\\Q\\¡ý\x17qqRìF\x9c\x84Ý´tÔDL÷M\x10W\x17ÿSD\x86ëè¹\x89»®WAP\x04\x01\x91\x1fD\x0e^âgGQ=@ðmnñE\x1d\x7f\x1dn5]YVýB\x1c\x15=Q=EBYÑ\x1f^P\x1cÍÿUuFu}ÑUÕUmD\x91¹:EÖÏp)\\WÔ~_Øk±n\x80Ôw^QÝÔEõEõç×Ó\xa0P`DÜ I\x1fßeß\x91__ULÃJ\x81wÙÜÇQ/\x11w\x7fdõ×Ñ+ÉÁ©F¼WmIi]\x19\x7f\x7f÷\x16ÕJ£\\GÕt\x17Ô\x05]\x19G×ý_\x07OUÃõSÿwµ\x05\\P=ÿ}\x98õ`UÖUAÔUñL;¤gõUB\t<¿ôÉ¥U{L\x03åÿý\x7fõrÕ`FWÍ_§ýWõt\x11\x7f5ÆbëA>\x1e\x92y\x97µy§ÝeÑÿõÎÔêKQ\x15m5õGDè)Û\x1f\x14Ùº>\x01^~f^UÚ.Uõå]Õ\xa0\x15à\x04(\x9f\\\x17\x90ª¿P÷FH\x1dÏE\x88\x0c;`\x10H\x00t8\x14\x17å\x1cV$=\xa0\x954½|\x10\x01¿\x1bÇW½ xìm`\xa0·ç\n@"\x08!\x15\x17\x95ßÞd\x94\xa0zÃ1h0\x0e×þUÕÔ(¥Q±@A\x05Nq\xa0ê\x85\x07ü¹\x99ÝUÖTÀÐBÅÁäþWÕWÜÖ\xa0d\x03¶*"\tv!\x82¢\x0e.¼ñ5]Ù\x14Aª\x00*\x17\x0f1ÑKó~hÜ\x9f<\x7fw¤\x15\x15c\x80~\x1a\x1c)åP\x1cÿù±Íè\x88 Ù{ûºÕ]ûQqT%@\x04\x00,\x84ÈïP%\x18\x99\x16ªýUQQ]dªçåý}u\x1d]R\x9d \x04uH²\x8a\x02\x00o@\xad\x19\x10!\x15]ùÿ\x7fMI\xa0\x81\t\x17ÕÕu[æµå>è\'\x8bàè\x81\x01 \x04\\\x12éjýEÕvEÔm\xa0èy4\x05WÁQOÖU½}\'ÿH*©±*cæÿ.3UçW\x1cÿ\x92Ý¨Î\xa0ô\x14DEUuSå÷ýU``%\x81¹£\x0f\x9eú¿µULLQ_ý]¨L%Tña\x06@\x1cÙwÿýw\x1eC\x00\x8dí\x00q\x12Ì\x99)\x18\x11\x01\x15W]]h\x91#µ]Ó\x14\x96]y\x1f×U½ä-;öp§|A\x00`A0\x01\x11AùE¥¨¬A×Ñs\x1fÉUÂ}w\x7f\x17Y\x88¸ê]\x08 b\x80\x80ÝT\x7fUEÒ\x9fý0&øu¹Y¹k\x96G½\x7f\x7f\x15\x9d%}Ô\x111\x00\x10AUWaW\x15_^Må9\x1d\x0bÕ´ßùÓ\x0eU×UtFeLA\x14\x80\x1bï÷\x7fÿwÉÞU\x7f^÷õ\xa0\x98\x98WÑ]¥$A|\x1b\x19\x05ª\x0f|\x00\x00"¿ÿÿÿÿY7T}u\x7fýýå\x86AQ\x0bõ\x85A\x10CT)\x15øÎ0\x00\x0bÕ\x10GÝ\x7fÿñµôSÑ]ýu .¨UàU¤¿r@5àgÐ\x01T\x03õõUWvïÿö×\x0eÜ@Ýÿõä\x04\x8aÑ\x97T´2+\x08F\x00\x9c\x83-C¯\xa0âª®»ó/ü^Q{u]\x7fý ±k}P\x97÷\x13y\nîH6Ac_U7×UUUUUT}CÕÕ\x1d}õ¨ª\x89y\x83ô&\x199\r\x9aJÑ^üe}óøJ°x! RÔO\x85G]ý´¨äÁu^rµ\x07å\'ÝU\x04æÆÁñz\x08E\x15Q\x15QW\x07TC~ÿ\x7fô¨\x88 |ûP&\x06_kÓ¨\r¶\x06ßÿQ]\x04WÕÕQmßYE·ß\x7fõ¨L\x01ÝeX§hUÕG\x0f\x9f\x90\x00^Wé¯j¿çÞWÕýÿïUß\x7fõh\x9c\xadVÄÍf¿Æ®ëßV\x192\x9e\x7fÈ\x02\x01UOµyUgÿ|»·\x7fðø¯\x89<\x97ì\x9d×}Y]y}AG\x10\x07¢\xa0 \x01~óÇOÑUõ^]ÿýà}tÕW\x15UIõÕÕ\x01wòñRP\x0fâ \xad\x7fßOU\x15W]p_ýýhü6E}\x15\x17egð\x1e÷WõÚZJ¬ª\x00\x85ý\x7fC}@\x9dW\x87ý\x7fôñ\x86\x03À\x00U\x14E]\x11V}¿_Ô^\x00 \x02=\x01ßÝNAÄ\x13T\x15]}wß\'IBq\x171]ôßýÿýÿ\x97T¢ª\x8a(¯\x7f÷j\x1f\\\x14ÍQu_Uw\x15Ûu\x91\x7f]v×}÷×Ut_^\x82¢ª\x007\x7fõëoñ\x05A\x01ýöuvßÑ¹¯¼}\x19wåö\x1fy\x94ßb\x02î®A\x95w_ÿuS\x85ÕWß\x7f\x15\\û¯Z\x1d\x04Ù\x99?WöÿWwÕsàª*±%W\x7fõ¯G\x04EWßm\x15}ñwöp\x01¥û~?SuUTOY+\x82¨T=^ßÕõ\x7fUTS×ÿõ5bÝ\x17AÎEÇtü]UZ¶æmhª\x8bÞ\x8dýÿ\x7fÕöµkÿßïõõÏU\x15\x126\x07EöôçwÇT\x15v*$UrFQ\x7fÿ×\x17\x15ÿÿÿûýu%@Y2\x99:ÔQ\x05åÖID\x1a\x7fª \x0bò\x03\x1fßÿ÷\x04×å}]\x7fõý\x9dGôjÁñ\x00\x991\x17\x95TJ·ß\x80¢ªª(»Õwô\r7wÕU}UÕ\x11^çºIP\x001Ñ\t3\x90_\x07vª¯Á¢\x1aoñMôqU\x1d¨^]WõGß\x9céJDõT×tg#\x96\x06{÷~\x82>\x00Ì[µeUY5\x11TU]õ]\x9cn\x0e,UVÁq<æc\x88iÝö¥pª\x85\x00\n\x97waÝ\x19\x17Õ\x15TUÅµ\x08}wú¿hVÐ\x0eAQSVV\x00ê\x04\x00\xa0)\x1d]}õtKV¿Uõ\x04!\x87\x1e]T\x1dCÌgÉð\x07O\x7f_\x06$\x08\x00\x00\x18\ruWÅ^ÿÝq\x15Õ\x04uD\x8ao3÷Í\x1fÅ\x95N®%}p\x99\n"\x82\xa0\x00³eÿ&]G_õUU<V/Ø?³\x92G\x1c\x14\x03\x1dÑÝ×ðòu]B\x00\x80\x01]||½ßU\x05×U°\x15tM_ÝG\x18ù\\¿±!Û\x7f÷W\x17Uú\x8a¢%×ýÑ÷Â{MUÕ\xa0·Z}ÿVwñøÿõèmw\x7fÿW\x82ÕN\x86¢%ÿÖ\x1f\x7fÉUýUU\x05Ñk½UaTaÖÝöB½TWÿ\x05§P½Jªµ\x7fP4_ùwÿUõ\x99·ãe\x15Áß\x15 G\x92õ^.ÿÿQx=`ýZ\x8dý\\%De}\x99SÕ\x10ý\x85\röÃU©\x9b\x97\x10\x0ec\x1d\x15ÿý ...

# %% [markdown]
# ### SteganoGAN predict random data with metrics

# %%
cover_image = tf.random.uniform([1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS], -1, 1, dtype=tf.float32)
message = tf.cast(tf.random.uniform([1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH], 0, 2, dtype=tf.int32), tf.float32)

stego_img, recovered_msg = steganoGAN.predict([cover_image, message])

print("stego_img min: {0}, max: {1}".format(tf.reduce_min(stego_img), tf.reduce_max(stego_img)))
print("recovered_msg min: {0}, max: {1}".format(tf.reduce_min(recovered_msg), tf.reduce_max(recovered_msg)))

print("BinaryCrossentropy: {0}".format(BinaryCrossentropy(from_logits=False)(message, recovered_msg)))
print("PSNR: {0}".format(tf.reduce_mean(tf.image.psnr(cover_image, stego_img, 1))))
print("SSIM: {0}".format(tf.reduce_mean(tf.image.ssim(cover_image, stego_img, 1))))

# %% [markdown]
# ----

# %% [markdown]
# ### Testing different functions

# %%
# Create two random tensors
tensor1 = tf.random.uniform((4, 128, 128, 2), minval=0, maxval=1, dtype=tf.int32)
tensor2 = tf.random.uniform((4, 128, 128, 2), minval=0, maxval=1, dtype=tf.float32)

# Calculate binary crossentropy
loss = BinaryCrossentropy(from_logits=False)
loss = loss(tf.constant([0, 0, 0, 0]), tf.constant([1, 1, 1, 1]))
#loss = loss(tensor1, tensor2)

loss.numpy().astype(np.uint8)

# %%
x = tf.constant([-1, -15, 0, 5])

ones = tf.ones(tf.shape(x))
zeros = tf.zeros(tf.shape(x))

tf.keras.backend.switch(x > 0, ones, zeros)

# %%
x = tf.constant([0, 0, 0, 0])
y = tf.constant([1, 1, 1, 1])

mse = tf.keras.losses.MeanSquaredError() 
mse(x, y).numpy().astype(np.uint8)
