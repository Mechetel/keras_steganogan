# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import tensorflow as tf
import numpy as np
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.utils import plot_model

from models import steganogan_encoder_dense_model, steganogan_decoder_dense_model, steganogan_critic_model
from keras_steganogan import KerasSteganoGAN

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 2
BATCH_SIZE = 4
MODEL_PATH = 'pretrained_models/steganoGAN_similarity.keras'

# %% [markdown]
# ### Call main encode and decode functions (with creating steganographic image and decoding it)

# %%
steganoGAN = KerasSteganoGAN(image_shape=IMAGE_SHAPE, data_depth=MESSAGE_DEPTH, model_path=MODEL_PATH)
steganoGAN.encode('input_1.png', 'images/output_similarity_1.png', 'Hello, World!')
steganoGAN.decode('images/output_similarity.png')
# Out:
# 'Hç½}nøÀ{h¾±\x8cr\x9dª\xadêªªZ\x00\x11Öñ4A\x17ù¶k\x11\x842?\x04\x10Pri}J¿\x16çÓ\x00P\x02@\x00\x02ªÈ*h¾D\x00\x00\x00H\x97tnË£@\x00\ns\x1b\x06(³5\x9b²_¿ÕÛ÷u[Ä\x1e}÷\xa0**\xa0\x82Ü:¢\x01°äº\x0b@Ð\x98§8I6~;=&2Ä\x945äð\\\x13\x92ì¨¢bvNbDä\x19ú\x86\x06U.\x83\x1eò7i³ôÂµO~Îâî¤ú®²\x12\x8b)\x88vb¡òlôÎ\x89{þ\x19\xa0K7î¹\r½#\x83ÜÙ´C^p!´ð\x07B\x9cK`_ÐúÃ;\x02ÓQç\x18ð³Æ>]\x86÷\xadÌª\x1cx&ã±ñx¦\x0c\x91Å`y\x8f8\x83gº\x19æiõ!³Í¼\x137\x9a\x87ýÂ:t\x1azîà6f)òÃc\x1ajÃ\x88\x1f!\x13f`t\x7f³N)©Òñ\x0fÙ\x8bjä\x06ú5w°\x18¡éø|\x87±\x16Ë\x1e\x00xù¼ð\x1bóV6½Sf¦îå\x96ÏðôLe\xa0\x80kWçð·\x1eK\x80Ç\x88_Ìb$\x8d\x16M+\x93±\x9a\x86í¶mQ4{ªè(îã3\x9fÀ÷:\x10ÉÏ\x8c\x1f\x04\x9f :ù³ÍR¯sòÙ\x8aøÓ²x\x00\x00\x02\x82k¿i zÓ»\x1eq£\x88ª\x03\x9f4\x04$<½\x16±\x9cI¤\x11ü\x93`¯û¢\x0b\x03ëá\x83£\x89ÖÝ==\x7flüg>îªÉ\rR1\x0eê×\n\x18Bù¿ÿùÿ\x95Âðþ\x06NÂn&]WN?=ÌmD¿ê¨\x9b»ûíáO4{WT|P¸M\x85ÌìÞ\x8b\x914,\xa0"\x0cÌÝÜ\x00.¿|~5\xad5c"ÿu\x00\x00\x10\x00"Ú\x07à\x88ô\x85à°°Ñ²³uÎØ\x00ß\x1b\x1eWúÃ\x1bý}ß[\x0eª\x8a\x08¯\x80\x7f\x00f\x92É3Ì²©³;\'qh\x8b@ppé,8K\x02¨úb"ââ«8\x01ø\x01lC¹Î\x90æ\x07dÃlÎ\x7f2q\'ÒC\x85×ÖÎ\x1a\x10p\x01\x91\x1b\x11à:P>\x82\x9aÎËóó\x08z\x03\x1f;\x1f"re\x94ÉaH´EØöcºnåíò¼Dö\x84Îc\x85ûDÄäî/\x1a\x0c&«\x9b?ô\x9fâOçµ\x1afß`G¡{3´Ëcñ\x90\x07Å¸¨[?c\x83p³kÃl\x14\x00¼À\x00\x00\x02vÿ\x0e\x08\x01pnð"XÈ"\x83\x81Ú\x00\x98Ìï\x83hó\x0eJ«ïÿðïÿÿûfÓ.È(2\'ðã\x8dýwëo°\xa0fú|ìâ¸\x1bÿ¿»¾\x8c«ÿÕKfÃ2cÄá%°É\x17¼£:\x83\x80?3\x12ôK\x8cÇwÕUU\x14\xadÔT\x00\x06ôË!7ª\xa0æp#\x9e\x1e`\x13\x06Ãÿê%¸Öê:´È \x00\x00ìâ\x83\x88\xadöf\nÇ\x07#\x0cp\x88CøbÌã²Á"9Ë>y÷\tc\x00\x11\x03í^`,}³\x17,w\x8a8\x830\x80"\x15²ËkÌÂ1\x16Èõ\x82ó1ü!â«gøâÞ\x80vç\tç,ÅÛp#\x1d7÷\x9b<«\xa0!¸,4ÚË"p¨x\x14?\x93¢s~4R\x0eo\x80háp\x83d¨l\x0cL\x90é|Ãq_3u{ø\x1cu\xa0äóô\x8dc2ÿ\x0cø i\x900\x03{0\x00"Ì#v,Î9±Å\x83\x9d\x9c\x02\x86"oç\x89ñ.zÊ\x00\x82cÀ·°£\x96¶\xa0ûr{«ýä\x86Ê{/\x8a\x8c%âçd\x15&t¤¡\x00\x03\x7f\x8cY\x1cr£w\x13þò`&\x00\x08n±"\x06\x82ZxyòËo\x8aÒêö\x18\x07ºë¿À°0£\xad2|S\x15]]\x7f|\x9a]ÿX÷Àq\x83\x85$(,ò\x1cÙ\x15UUUé°p£s\x9ap\x8b?pï»ùÏéØa<Î\x0bãã=§}è\x03\rü\x00(\x00À ²£Hfqlt \x11\x82\x08ÝWÝ#^¹!\x0fft~må\nÍ\xa0\x80Ø\xa0ð\x07°£r\x1eÊ\t°\n\x87\x83 \x93\x07\x82\x02üÌ\x12ä³lè,."úH¨(\x00öÿ0£\x88G\x18\x14úÎ\x1bÁ>\x02\x8f\x87ë\x05ë¿XQ¨"\x820hª\x02 \x00\x00åø\x02£8\x87N\x87\x7fì\x87Ì¶è$7Ç\x139U\xa0+îèºî¼È\x82ò¢ãàà\x1b#\x82\x17\x9b®À&\x19ø²Ì\x04±k\x94ò¾´\x05\x81U\x10\x00\x00\x03$Î\x8b«à@3£á!üe)d\x83ø±lÀB\x84§\x05)\x1a\x82\x08*\x01-¸@û%ÃE¶C{#ä£À|©f^<û\x93:Ï`{k\x92\x07\x17\x10\x06\x07\x1d\x7f\x7fë%è¡¦G\x03£\x92³Ê\x1d\t\'ùLÍâÖÏ;°êø@xú¯\x8fþ¾¿O\x11ø\x0cæl##²=Ùd=~W\x9aø\x82s \tã>£®\xa0\x00}EQTF\x0e\x06Þ\x8cæló£s1\x88$¿uÇÑdäÆÎj\x80\x19\x03)\x16\x9fÞ®®ê§\'_é\x15æ\x0c[\'á°LlÑgÆÂ×Âo/0\x17ë\rßt\x10\x00\x11UQ\x7f\x94ª"\rçGÛ£pò¼|Â/ÖËsFI38óòÿë¾îþê»¾Î)\x808\rçoÃ§\x83Yì|È7kÄ\x9a&ï8ç%ñw\x00\x0fÝ\x7f·ßýÆ\nf7Ì÷G\x8b£b\x1fr4Þo\x02Ë7¦\x88>\x1eÀø0\x00\x00\x9a\\\x0eÀ\t"I\x93\x9f\x05¢M\x8b\'ü"@~Às(çí\x97)\x90§JX0¢BB¢\xa0(\x0f"Üt\t\x81ÆeK£Ô\x92fÝº/\x92åÙm\x99\x05-¹(ps\x0bhè\x192\x9e&ç"N\x0fð\x7f\x8b£2³\x8fÿ(¤j\x8a¢\x00¢**\x8bg\x8a\x99\x00"º¿\x92\x1e&Åêº®ðDY·Ñ\x93Å\x051ö=\x7fçÝÿýPxv(®*ÿïÜhÿ3!ÕõYò`\x80\x9ep£\x19G7ßÕ±¿åÝðê¬p\x0fÛøü\x83À¢>6û\x80A\x80âoÖ\x07È\x0bËª$á²Ì0\x92j\x83Õ¬ð478ü$"\x83, ¹\x81Ê,âiÏWö\x8b\x12\x00\xa0hÈÉ\xa0h\x03\x88¨q\x90\x8e\x84\x83|?\x85È\x0f£\x19¢\x83ÍâJ\x1c"Ë¥«\x81\x82âMÏ\x83ê¨\xa0\x03ààãY\x83t7£\x03\x1c¢\x0f8\x8f\x81ön\x0c\x83³\x82\x0f¢c\x82\x87\x81\x8fÍ³ \x8b<àÈði|ö`iì\x0e<D\xa0!ó\x0f®ªÊ\x8c%Hó\x03³ëº,\xa0\x82C\x08ÓÆ4£¨\x11\x11lv3ý¸×íòG\x103°+\x8e:JÀ\x01í¨\x10\x01É[´@\x9bù¨\x10\x9a|\x1b95\x9cWª©â\x0fè¢\'°\x1cÜQÀ\x0b\x0b*¬ÚFæ¬ã\x0c\x14[\x83puü\x17<\x1c\x0b\x83@à\x05lÃm\x95ô*ïã¿,?Ó\x8b¹\x8d°\x91\x04¤¸*\x12\x1e^¼0Î`\x04\x08ò¤\x16Ë0\x83ó2I\x17vj\x8e°\x04VëdØ\x8a\nn\x15PT\x01ð0±\x1b«\x17P0\x17_\x0fãNjL\x15Ì\x1cÀìû#\x1f=\x80\x02åV¿»à\x01h°Ìm\x7f§»7·&aú\x07Ö·ÿ\x87\x00àÍ¿\x96ãÌ`Ç_\x97×WEÿ\x01\x80rM\\\xad\x81ü?"t~3À[í¤\x02ÏîQç\x05-1Ý&*h\x8a?þ^\x04ø\x1b\x84ì\x8ax\x1c¢br3¥å\x82}»K0ã\x14¯Õó` ª\x87ß\x9c\x17¹ð\x10\x1b\x1a3Û\n\x00\x93Á2ã.\x81¡6ò\x04\x0b¶\r8RÙ¢\\õ]Õæ©Dö6\x0eÙ=\x9f\x06\x86ba²ï÷(î\x10\x1a2\x17ÛÃò\x9dÂ\x1aÄI¤(]öCS;\x08\x08µ\x9e/\xa0\x83h)\x01\x86à\x02Ï\x9fð©D}y\x9cÀ\x ...

# %% [markdown]
# ### SteganoGAN predict random data with metrics

# %%
cover_image = tf.random.uniform([1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS], -1, 1, dtype=tf.float32)
message = tf.cast(tf.random.uniform([1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH], 0, 2, dtype=tf.int32), tf.float32)
stego_img, recovered_msg = steganoGAN.predict([cover_image, message])
print("BinaryCrossentropy: {0}".format(BinaryCrossentropy()(message, recovered_msg)))
print("PSNR: {0}".format(tf.reduce_mean(tf.image.psnr(cover_image, stego_img, 1))))
print("SSIM: {0}".format(tf.reduce_mean(tf.image.ssim(cover_image, stego_img, 1))))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# BinaryCrossentropy: 1.3282517194747925
# PSNR: 17.170175552368164
# SSIM: 0.6067938208580017

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic  = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()
#plot_model(steganoGAN.encoder, to_file='model_images/encoder.png', show_shapes=True, show_layer_names=True)
#plot_model(steganoGAN.decoder, to_file='model_images/decoder.png', show_shapes=True, show_layer_names=True)
#plot_model(steganoGAN.critic, to_file='model_images/critic.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

def normalize_img(img):
    return (img / 127.5) - 1

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

def create_message_tensor_for_training(batch_size, width, height, data_depth):
    message = tf.random.uniform([batch_size, width, height, data_depth], 0, 2, dtype=tf.int32)
    message = tf.cast(message, tf.float32)
    return message

def create_message_dataset(batch_size, num_batches, width, height, data_depth):
    message_tensors = [create_message_tensor_for_training(batch_size, width, height, data_depth) for _ in range(num_batches)]
    return tf.data.Dataset.from_tensor_slices(tf.concat(message_tensors, axis=0)).batch(batch_size)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=10, validation_data=val_ds)
steganoGAN.save(MODEL_PATH)
# Out:
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 229s 1s/step - bpp: 2.0000 - critic_loss: -0.0027 - decoding_loss: 0.6424 - encoder_decoder_total_loss: 1.2077 - psnr: 32.6068 - realism_loss: 0.5080 - similarity_loss: 0.0573 - ssim: 0.9566 - val_bpp: 2.0000 - val_critic_loss: -6.5629e-04 - val_decoding_loss: 0.6419 - val_encoder_decoder_total_loss: 1.1764 - val_psnr: 34.9229 - val_realism_loss: 0.5001 - val_similarity_loss: 0.0344 - val_ssim: 0.9659
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 220s 1s/step - bpp: 2.0000 - critic_loss: -0.0016 - decoding_loss: 0.6275 - encoder_decoder_total_loss: 1.1706 - psnr: 34.9173 - realism_loss: 0.5104 - similarity_loss: 0.0327 - ssim: 0.9677 - val_bpp: 2.0000 - val_critic_loss: -3.6327e-04 - val_decoding_loss: 0.6327 - val_encoder_decoder_total_loss: 1.1617 - val_psnr: 36.3578 - val_realism_loss: 0.5053 - val_similarity_loss: 0.0237 - val_ssim: 0.9738
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 220s 1s/step - bpp: 2.0000 - critic_loss: -0.0015 - decoding_loss: 0.6119 - encoder_decoder_total_loss: 1.1543 - psnr: 34.7149 - realism_loss: 0.5079 - similarity_loss: 0.0345 - ssim: 0.9648 - val_bpp: 2.0000 - val_critic_loss: -2.3150e-04 - val_decoding_loss: 0.6148 - val_encoder_decoder_total_loss: 1.1458 - val_psnr: 34.7152 - val_realism_loss: 0.4965 - val_similarity_loss: 0.0345 - val_ssim: 0.9672
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 222s 1s/step - bpp: 2.0000 - critic_loss: -0.0016 - decoding_loss: 0.5959 - encoder_decoder_total_loss: 1.1412 - psnr: 34.3308 - realism_loss: 0.5078 - similarity_loss: 0.0374 - ssim: 0.9619 - val_bpp: 2.0000 - val_critic_loss: -1.7143e-04 - val_decoding_loss: 0.5940 - val_encoder_decoder_total_loss: 1.1382 - val_psnr: 34.3696 - val_realism_loss: 0.5064 - val_similarity_loss: 0.0378 - val_ssim: 0.9614
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 220s 1s/step - bpp: 2.0000 - critic_loss: -0.0018 - decoding_loss: 0.5815 - encoder_decoder_total_loss: 1.1334 - psnr: 33.8627 - realism_loss: 0.5102 - similarity_loss: 0.0417 - ssim: 0.9595 - val_bpp: 2.0000 - val_critic_loss: -0.0011 - val_decoding_loss: 0.5724 - val_encoder_decoder_total_loss: 1.1293 - val_psnr: 33.4940 - val_realism_loss: 0.5112 - val_similarity_loss: 0.0456 - val_ssim: 0.9574
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 223s 1s/step - bpp: 2.0000 - critic_loss: -0.0020 - decoding_loss: 0.5650 - encoder_decoder_total_loss: 1.1203 - psnr: 33.4031 - realism_loss: 0.5091 - similarity_loss: 0.0463 - ssim: 0.9554 - val_bpp: 2.0000 - val_critic_loss: 1.9529e-05 - val_decoding_loss: 0.5652 - val_encoder_decoder_total_loss: 1.1840 - val_psnr: 33.3536 - val_realism_loss: 0.5716 - val_similarity_loss: 0.0472 - val_ssim: 0.9560
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 224s 1s/step - bpp: 2.0000 - critic_loss: -0.0024 - decoding_loss: 0.5471 - encoder_decoder_total_loss: 1.1158 - psnr: 32.9204 - realism_loss: 0.5172 - similarity_loss: 0.0516 - ssim: 0.9531 - val_bpp: 2.0000 - val_critic_loss: -0.0018 - val_decoding_loss: 0.5380 - val_encoder_decoder_total_loss: 1.1302 - val_psnr: 32.3349 - val_realism_loss: 0.5301 - val_similarity_loss: 0.0621 - val_ssim: 0.9559
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 225s 1s/step - bpp: 2.0000 - critic_loss: -0.0026 - decoding_loss: 0.5308 - encoder_decoder_total_loss: 1.1057 - psnr: 32.5821 - realism_loss: 0.5186 - similarity_loss: 0.0562 - ssim: 0.9522 - val_bpp: 2.0000 - val_critic_loss: -0.0022 - val_decoding_loss: 0.5263 - val_encoder_decoder_total_loss: 1.0975 - val_psnr: 32.5784 - val_realism_loss: 0.5155 - val_similarity_loss: 0.0556 - val_ssim: 0.9542
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 221s 1s/step - bpp: 2.0000 - critic_loss: -0.0032 - decoding_loss: 0.5172 - encoder_decoder_total_loss: 1.0965 - psnr: 32.3005 - realism_loss: 0.5193 - similarity_loss: 0.0600 - ssim: 0.9508 - val_bpp: 2.0000 - val_critic_loss: 3.0416e-04 - val_decoding_loss: 0.5157 - val_encoder_decoder_total_loss: 1.1131 - val_psnr: 32.1934 - val_realism_loss: 0.5363 - val_similarity_loss: 0.0610 - val_ssim: 0.9494
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 219s 1s/step - bpp: 2.0000 - critic_loss: -0.0036 - decoding_loss: 0.5063 - encoder_decoder_total_loss: 1.0859 - psnr: 32.1154 - realism_loss: 0.5167 - similarity_loss: 0.0629 - ssim: 0.9501 - val_bpp: 2.0000 - val_critic_loss: -0.0031 - val_decoding_loss: 0.5175 - val_encoder_decoder_total_loss: 1.1170 - val_psnr: 32.3082 - val_realism_loss: 0.5390 - val_similarity_loss: 0.0604 - val_ssim: 0.9555

# %% [markdown]
# ----

# %% [markdown]
# ### Testing different functions

# %%
from tensorflow.keras.losses import BinaryCrossentropy

# Create two random tensors
tensor1 = tf.random.uniform((4, 128, 128, 2), minval=0, maxval=1, dtype=tf.int32)
tensor2 = tf.random.uniform((4, 128, 128, 2), minval=0, maxval=1, dtype=tf.float32)

# Calculate binary crossentropy
loss = BinaryCrossentropy(from_logits=False)
loss = loss(tf.constant([1, 1, 1]), tf.constant([1, 1, 1]))
#loss = loss(tensor1, tensor2)

loss.numpy().astype(np.uint8)

# %%
first_value = next(iter(train_ds.take(1)))
print(first_value)
