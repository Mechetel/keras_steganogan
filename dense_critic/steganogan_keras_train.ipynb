# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy

from models import (
  steganogan_encoder_dense_model,
  steganogan_decoder_dense_model,
  steganogan_critic_model
)
from keras_steganogan_critic import KerasSteganoGAN
# Out:
# 2024-08-21 21:51:46.793143: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 2
BATCH_SIZE = 4
MODEL_PATH = '../pretrained_models/steganoGAN_dense_critic.keras'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

def normalize_img(img):
    return (img / 127.5) - 1

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

def create_message_tensor_for_training(batch_size, width, height, data_depth):
    message = tf.random.uniform([batch_size, width, height, data_depth], 0, 2, dtype=tf.int32)
    message = tf.cast(message, tf.float32)
    return message

def create_message_dataset(batch_size, num_batches, width, height, data_depth):
    message_tensors = [create_message_tensor_for_training(batch_size, width, height, data_depth) for _ in range(num_batches)]
    return tf.data.Dataset.from_tensor_slices(tf.concat(message_tensors, axis=0)).batch(batch_size)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=10, validation_data=val_ds)
steganoGAN.save(MODEL_PATH)
# Out:
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 273s 1s/step - bpp: 2.0000 - critic_loss: -0.0011 - decoding_loss: 0.6687 - encoder_decoder_total_loss: 0.8197 - psnr: 8.6626 - realism_loss: -1.0366e-05 - similarity_loss: 0.1509 - ssim: 0.3587 - val_bpp: 2.0000 - val_critic_loss: -0.0060 - val_decoding_loss: 0.4506 - val_encoder_decoder_total_loss: 0.5354 - val_psnr: 10.6741 - val_realism_loss: -0.0013 - val_similarity_loss: 0.0862 - val_ssim: 0.3750
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - bpp: 2.0000 - critic_loss: -0.0106 - decoding_loss: 0.1649 - encoder_decoder_total_loss: 0.2410 - psnr: 11.0368 - realism_loss: -0.0044 - similarity_loss: 0.0805 - ssim: 0.3469 - val_bpp: 2.0000 - val_critic_loss: -0.0254 - val_decoding_loss: 0.1287 - val_encoder_decoder_total_loss: 0.1907 - val_psnr: 11.0724 - val_realism_loss: -0.0170 - val_similarity_loss: 0.0790 - val_ssim: 0.3695
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - bpp: 2.0000 - critic_loss: -0.0300 - decoding_loss: 0.0672 - encoder_decoder_total_loss: 0.1043 - psnr: 12.2998 - realism_loss: -0.0236 - similarity_loss: 0.0607 - ssim: 0.4009 - val_bpp: 2.0000 - val_critic_loss: -0.0450 - val_decoding_loss: 0.0481 - val_encoder_decoder_total_loss: 0.0818 - val_psnr: 11.9638 - val_realism_loss: -0.0310 - val_similarity_loss: 0.0647 - val_ssim: 0.4077
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - bpp: 2.0000 - critic_loss: -0.0450 - decoding_loss: 0.0462 - encoder_decoder_total_loss: 0.0586 - psnr: 13.3541 - realism_loss: -0.0353 - similarity_loss: 0.0477 - ssim: 0.4538 - val_bpp: 2.0000 - val_critic_loss: -0.0492 - val_decoding_loss: 0.0368 - val_encoder_decoder_total_loss: 0.0453 - val_psnr: 13.4813 - val_realism_loss: -0.0378 - val_similarity_loss: 0.0463 - val_ssim: 0.4785
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - bpp: 2.0000 - critic_loss: -0.0491 - decoding_loss: 0.0399 - encoder_decoder_total_loss: 0.0409 - psnr: 14.0357 - realism_loss: -0.0400 - similarity_loss: 0.0410 - ssim: 0.4930 - val_bpp: 2.0000 - val_critic_loss: -0.0486 - val_decoding_loss: 0.0338 - val_encoder_decoder_total_loss: 0.0302 - val_psnr: 14.2959 - val_realism_loss: -0.0425 - val_similarity_loss: 0.0388 - val_ssim: 0.5220
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 290s 1s/step - bpp: 2.0000 - critic_loss: -0.0491 - decoding_loss: 0.0382 - encoder_decoder_total_loss: 0.0315 - psnr: 14.5714 - realism_loss: -0.0431 - similarity_loss: 0.0365 - ssim: 0.5242 - val_bpp: 2.0000 - val_critic_loss: -0.0519 - val_decoding_loss: 0.0278 - val_encoder_decoder_total_loss: 0.0294 - val_psnr: 13.9425 - val_realism_loss: -0.0399 - val_similarity_loss: 0.0414 - val_ssim: 0.5155
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 302s 2s/step - bpp: 2.0000 - critic_loss: -0.0491 - decoding_loss: 0.0364 - encoder_decoder_total_loss: 0.0255 - psnr: 14.9318 - realism_loss: -0.0445 - similarity_loss: 0.0336 - ssim: 0.5455 - val_bpp: 2.0000 - val_critic_loss: -0.0497 - val_decoding_loss: 0.0295 - val_encoder_decoder_total_loss: 0.0152 - val_psnr: 15.1605 - val_realism_loss: -0.0464 - val_similarity_loss: 0.0320 - val_ssim: 0.5723
# Epoch 8/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - bpp: 2.0000 - critic_loss: -0.0489 - decoding_loss: 0.0358 - encoder_decoder_total_loss: 0.0208 - psnr: 15.2972 - realism_loss: -0.0460 - similarity_loss: 0.0310 - ssim: 0.5673 - val_bpp: 2.0000 - val_critic_loss: -0.0533 - val_decoding_loss: 0.0265 - val_encoder_decoder_total_loss: 0.0120 - val_psnr: 15.4213 - val_realism_loss: -0.0446 - val_similarity_loss: 0.0302 - val_ssim: 0.5882
# Epoch 9/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 308s 2s/step - bpp: 2.0000 - critic_loss: -0.0498 - decoding_loss: 0.0365 - encoder_decoder_total_loss: 0.0204 - psnr: 15.5596 - realism_loss: -0.0454 - similarity_loss: 0.0293 - ssim: 0.5840 - val_bpp: 2.0000 - val_critic_loss: -0.0525 - val_decoding_loss: 0.0243 - val_encoder_decoder_total_loss: 0.0085 - val_psnr: 15.3485 - val_realism_loss: -0.0462 - val_similarity_loss: 0.0304 - val_ssim: 0.5962
# Epoch 10/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 306s 2s/step - bpp: 2.0000 - critic_loss: -0.0505 - decoding_loss: 0.0367 - encoder_decoder_total_loss: 0.0209 - psnr: 15.7781 - realism_loss: -0.0438 - similarity_loss: 0.0280 - ssim: 0.5957 - val_bpp: 2.0000 - val_critic_loss: -0.0488 - val_decoding_loss: 0.0255 - val_encoder_decoder_total_loss: 0.0284 - val_psnr: 15.1779 - val_realism_loss: -0.0286 - val_similarity_loss: 0.0314 - val_ssim: 0.5868
