# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_residual_model,
  steganogan_decoder_basic_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-22 22:32:40.314725: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 1
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_residual.keras'
LOGS_PATH = f'../../logs/residual/{MESSAGE_DEPTH}/steganoGAN_residual.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/residual/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_residual_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - critic_loss: -8.3300e-04 - decoder_accuracy: 0.5722 - decoder_loss: 0.7226 - encoder_decoder_total_loss: 1.0095 - psnr: 6.3363 - realism_loss: -1.6312e-06 - rs_bpp: 0.1444 - similarity_loss: 0.2869 - ssim: 0.2668 - val_critic_loss: -0.0040 - val_decoder_accuracy: 0.8345 - val_decoder_loss: 0.5332 - val_encoder_decoder_total_loss: 0.5850 - val_psnr: 12.8688 - val_realism_loss: -7.5599e-04 - val_rs_bpp: 0.6691 - val_similarity_loss: 0.0525 - val_ssim: 0.4605
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 200s 999ms/step - critic_loss: -0.0087 - decoder_accuracy: 0.8927 - decoder_loss: 0.2761 - encoder_decoder_total_loss: 0.3647 - psnr: 10.6176 - realism_loss: -0.0010 - rs_bpp: 0.7854 - similarity_loss: 0.0896 - ssim: 0.3804 - val_critic_loss: -0.0230 - val_decoder_accuracy: 0.9759 - val_decoder_loss: 0.1383 - val_encoder_decoder_total_loss: 0.1854 - val_psnr: 12.4317 - val_realism_loss: -0.0114 - val_rs_bpp: 0.9517 - val_similarity_loss: 0.0586 - val_ssim: 0.4584
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 197s 980ms/step - critic_loss: -0.0289 - decoder_accuracy: 0.9767 - decoder_loss: 0.0778 - encoder_decoder_total_loss: 0.1079 - psnr: 13.4214 - realism_loss: -0.0168 - rs_bpp: 0.9534 - similarity_loss: 0.0469 - ssim: 0.4872 - val_critic_loss: -0.0414 - val_decoder_accuracy: 0.9900 - val_decoder_loss: 0.0459 - val_encoder_decoder_total_loss: 0.0577 - val_psnr: 14.1532 - val_realism_loss: -0.0279 - val_rs_bpp: 0.9800 - val_similarity_loss: 0.0397 - val_ssim: 0.5369
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 195s 970ms/step - critic_loss: -0.0435 - decoder_accuracy: 0.9885 - decoder_loss: 0.0417 - encoder_decoder_total_loss: 0.0394 - psnr: 15.4627 - realism_loss: -0.0317 - rs_bpp: 0.9771 - similarity_loss: 0.0293 - ssim: 0.5765 - val_critic_loss: -0.0581 - val_decoder_accuracy: 0.9933 - val_decoder_loss: 0.0283 - val_encoder_decoder_total_loss: 0.0279 - val_psnr: 15.7522 - val_realism_loss: -0.0281 - val_rs_bpp: 0.9867 - val_similarity_loss: 0.0277 - val_ssim: 0.6091
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 197s 982ms/step - critic_loss: -0.0569 - decoder_accuracy: 0.9908 - decoder_loss: 0.0329 - encoder_decoder_total_loss: 0.0239 - psnr: 16.5554 - realism_loss: -0.0320 - rs_bpp: 0.9817 - similarity_loss: 0.0230 - ssim: 0.6284 - val_critic_loss: -0.0607 - val_decoder_accuracy: 0.9932 - val_decoder_loss: 0.0261 - val_encoder_decoder_total_loss: 0.0192 - val_psnr: 16.8903 - val_realism_loss: -0.0284 - val_rs_bpp: 0.9865 - val_similarity_loss: 0.0215 - val_ssim: 0.6558
