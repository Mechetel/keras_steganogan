# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_residual_model,
  steganogan_decoder_basic_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-22 23:43:59.914483: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 5
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_residual.keras'
LOGS_PATH = f'../../logs/residual/{MESSAGE_DEPTH}/steganoGAN.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/residual/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_residual_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 218s 1s/step - critic_loss: -5.9710e-04 - decoder_accuracy: 0.5203 - decoder_loss: 0.7565 - encoder_decoder_total_loss: 0.9488 - psnr: 8.0372 - realism_loss: -2.1022e-04 - rs_bpp: 0.2027 - similarity_loss: 0.1924 - ssim: 0.3251 - val_critic_loss: -0.0059 - val_decoder_accuracy: 0.5541 - val_decoder_loss: 0.6841 - val_encoder_decoder_total_loss: 0.7144 - val_psnr: 15.3934 - val_realism_loss: 7.8507e-04 - val_rs_bpp: 0.5410 - val_similarity_loss: 0.0295 - val_ssim: 0.6221
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - critic_loss: -0.0087 - decoder_accuracy: 0.5964 - decoder_loss: 0.6677 - encoder_decoder_total_loss: 0.6990 - psnr: 15.3342 - realism_loss: 4.7250e-04 - rs_bpp: 0.9637 - similarity_loss: 0.0307 - ssim: 0.6093 - val_critic_loss: -0.0079 - val_decoder_accuracy: 0.6642 - val_decoder_loss: 0.6293 - val_encoder_decoder_total_loss: 0.6415 - val_psnr: 15.9625 - val_realism_loss: -0.0136 - val_rs_bpp: 1.6415 - val_similarity_loss: 0.0258 - val_ssim: 0.6251
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - critic_loss: -0.0110 - decoder_accuracy: 0.6882 - decoder_loss: 0.5884 - encoder_decoder_total_loss: 0.5964 - psnr: 15.8208 - realism_loss: -0.0189 - rs_bpp: 1.8821 - similarity_loss: 0.0269 - ssim: 0.5937 - val_critic_loss: -0.0236 - val_decoder_accuracy: 0.7249 - val_decoder_loss: 0.5489 - val_encoder_decoder_total_loss: 0.5451 - val_psnr: 15.5568 - val_realism_loss: -0.0325 - val_rs_bpp: 2.2486 - val_similarity_loss: 0.0288 - val_ssim: 0.6018
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - critic_loss: -0.0271 - decoder_accuracy: 0.7366 - decoder_loss: 0.5244 - encoder_decoder_total_loss: 0.5165 - psnr: 15.7945 - realism_loss: -0.0352 - rs_bpp: 2.3661 - similarity_loss: 0.0272 - ssim: 0.5887 - val_critic_loss: -0.0339 - val_decoder_accuracy: 0.7588 - val_decoder_loss: 0.4903 - val_encoder_decoder_total_loss: 0.4815 - val_psnr: 15.1622 - val_realism_loss: -0.0405 - val_rs_bpp: 2.5880 - val_similarity_loss: 0.0318 - val_ssim: 0.5739
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - critic_loss: -0.0358 - decoder_accuracy: 0.7654 - decoder_loss: 0.4753 - encoder_decoder_total_loss: 0.4652 - psnr: 15.1737 - realism_loss: -0.0418 - rs_bpp: 2.6542 - similarity_loss: 0.0316 - ssim: 0.5573 - val_critic_loss: -0.0395 - val_decoder_accuracy: 0.7816 - val_decoder_loss: 0.4425 - val_encoder_decoder_total_loss: 0.4358 - val_psnr: 14.5686 - val_realism_loss: -0.0437 - val_rs_bpp: 2.8162 - val_similarity_loss: 0.0370 - val_ssim: 0.5349
