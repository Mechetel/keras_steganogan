# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_residual_model,
  steganogan_decoder_basic_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-22 23:10:08.365204: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 3
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_residual.keras'
LOGS_PATH = f'../../logs/residual/{MESSAGE_DEPTH}/steganoGAN.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/residual/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_residual_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 208s 984ms/step - critic_loss: -5.6506e-04 - decoder_accuracy: 0.5370 - decoder_loss: 0.7556 - encoder_decoder_total_loss: 1.0056 - psnr: 6.8470 - realism_loss: -2.3687e-04 - rs_bpp: 0.2219 - similarity_loss: 0.2503 - ssim: 0.2649 - val_critic_loss: -0.0045 - val_decoder_accuracy: 0.6396 - val_decoder_loss: 0.6568 - val_encoder_decoder_total_loss: 0.7079 - val_psnr: 12.9701 - val_realism_loss: 1.2610e-04 - val_rs_bpp: 0.8375 - val_similarity_loss: 0.0510 - val_ssim: 0.4772
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 196s 977ms/step - critic_loss: -0.0083 - decoder_accuracy: 0.6953 - decoder_loss: 0.5861 - encoder_decoder_total_loss: 0.6378 - psnr: 12.9618 - realism_loss: -5.6965e-04 - rs_bpp: 1.1717 - similarity_loss: 0.0523 - ssim: 0.4989 - val_critic_loss: -0.0186 - val_decoder_accuracy: 0.7931 - val_decoder_loss: 0.4898 - val_encoder_decoder_total_loss: 0.5314 - val_psnr: 12.7146 - val_realism_loss: -0.0125 - val_rs_bpp: 1.7587 - val_similarity_loss: 0.0541 - val_ssim: 0.4775
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 190s 949ms/step - critic_loss: -0.0222 - decoder_accuracy: 0.8232 - decoder_loss: 0.4016 - encoder_decoder_total_loss: 0.4326 - psnr: 12.9977 - realism_loss: -0.0206 - rs_bpp: 1.9392 - similarity_loss: 0.0516 - ssim: 0.4560 - val_critic_loss: -0.0333 - val_decoder_accuracy: 0.8950 - val_decoder_loss: 0.2860 - val_encoder_decoder_total_loss: 0.3147 - val_psnr: 12.0996 - val_realism_loss: -0.0352 - val_rs_bpp: 2.3701 - val_similarity_loss: 0.0639 - val_ssim: 0.3919
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 194s 967ms/step - critic_loss: -0.0369 - decoder_accuracy: 0.9128 - decoder_loss: 0.2322 - encoder_decoder_total_loss: 0.2555 - psnr: 12.3585 - realism_loss: -0.0369 - rs_bpp: 2.4767 - similarity_loss: 0.0602 - ssim: 0.3887 - val_critic_loss: -0.0476 - val_decoder_accuracy: 0.9435 - val_decoder_loss: 0.1675 - val_encoder_decoder_total_loss: 0.2001 - val_psnr: 11.7824 - val_realism_loss: -0.0366 - val_rs_bpp: 2.6610 - val_similarity_loss: 0.0692 - val_ssim: 0.3503
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 197s 981ms/step - critic_loss: -0.0514 - decoder_accuracy: 0.9461 - decoder_loss: 0.1564 - encoder_decoder_total_loss: 0.1836 - psnr: 12.1935 - realism_loss: -0.0361 - rs_bpp: 2.6769 - similarity_loss: 0.0633 - ssim: 0.3605 - val_critic_loss: -0.0604 - val_decoder_accuracy: 0.9603 - val_decoder_loss: 0.1225 - val_encoder_decoder_total_loss: 0.1571 - val_psnr: 11.9722 - val_realism_loss: -0.0322 - val_rs_bpp: 2.7618 - val_similarity_loss: 0.0668 - val_ssim: 0.3469
