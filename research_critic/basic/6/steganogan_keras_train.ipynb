# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_basic_model,
  steganogan_decoder_basic_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-22 22:13:32.967454: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 6
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_basic.keras'
LOGS_PATH = f'../../logs/basic/{MESSAGE_DEPTH}/steganoGAN_basic.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/basic/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 210s 996ms/step - critic_loss: -8.8476e-04 - decoder_accuracy: 0.5207 - decoder_loss: 0.7513 - encoder_decoder_total_loss: 1.0828 - psnr: 5.7258 - realism_loss: 5.5282e-05 - rs_bpp: 0.2485 - similarity_loss: 0.3314 - ssim: 0.1806 - val_critic_loss: -0.0064 - val_decoder_accuracy: 0.5650 - val_decoder_loss: 0.6839 - val_encoder_decoder_total_loss: 0.7661 - val_psnr: 11.0929 - val_realism_loss: 0.0011 - val_rs_bpp: 0.7803 - val_similarity_loss: 0.0810 - val_ssim: 0.3180
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - critic_loss: -0.0073 - decoder_accuracy: 0.5811 - decoder_loss: 0.6754 - encoder_decoder_total_loss: 0.7592 - psnr: 11.0314 - realism_loss: -7.7070e-04 - rs_bpp: 0.9735 - similarity_loss: 0.0845 - ssim: 0.4220 - val_critic_loss: -0.0125 - val_decoder_accuracy: 0.6328 - val_decoder_loss: 0.6483 - val_encoder_decoder_total_loss: 0.6932 - val_psnr: 13.4005 - val_realism_loss: -0.0025 - val_rs_bpp: 1.5935 - val_similarity_loss: 0.0473 - val_ssim: 0.5056
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - critic_loss: -0.0147 - decoder_accuracy: 0.6512 - decoder_loss: 0.6261 - encoder_decoder_total_loss: 0.6857 - psnr: 12.2596 - realism_loss: -0.0046 - rs_bpp: 1.8147 - similarity_loss: 0.0643 - ssim: 0.4305 - val_critic_loss: -0.0173 - val_decoder_accuracy: 0.6850 - val_decoder_loss: 0.5950 - val_encoder_decoder_total_loss: 0.6235 - val_psnr: 14.1725 - val_realism_loss: -0.0109 - val_rs_bpp: 2.2203 - val_similarity_loss: 0.0394 - val_ssim: 0.5466
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - critic_loss: -0.0205 - decoder_accuracy: 0.6979 - decoder_loss: 0.5775 - encoder_decoder_total_loss: 0.6189 - psnr: 13.0144 - realism_loss: -0.0126 - rs_bpp: 2.3749 - similarity_loss: 0.0540 - ssim: 0.4505 - val_critic_loss: -0.0270 - val_decoder_accuracy: 0.7206 - val_decoder_loss: 0.5511 - val_encoder_decoder_total_loss: 0.5692 - val_psnr: 14.5472 - val_realism_loss: -0.0187 - val_rs_bpp: 2.6471 - val_similarity_loss: 0.0368 - val_ssim: 0.5486
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - critic_loss: -0.0323 - decoder_accuracy: 0.7311 - decoder_loss: 0.5335 - encoder_decoder_total_loss: 0.5747 - psnr: 12.7533 - realism_loss: -0.0164 - rs_bpp: 2.7729 - similarity_loss: 0.0576 - ssim: 0.4310 - val_critic_loss: -0.0388 - val_decoder_accuracy: 0.7431 - val_decoder_loss: 0.5142 - val_encoder_decoder_total_loss: 0.5358 - val_psnr: 14.3513 - val_realism_loss: -0.0175 - val_rs_bpp: 2.9167 - val_similarity_loss: 0.0391 - val_ssim: 0.5272
