# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_basic_model,
  steganogan_decoder_basic_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-22 21:54:43.220604: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 5
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_basic.keras'
LOGS_PATH = f'../../logs/basic/{MESSAGE_DEPTH}/steganoGAN_basic.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/basic/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_basic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - critic_loss: -6.9263e-04 - decoder_accuracy: 0.5139 - decoder_loss: 0.7618 - encoder_decoder_total_loss: 1.1303 - psnr: 5.2323 - realism_loss: -1.6014e-04 - rs_bpp: 0.1386 - similarity_loss: 0.3687 - ssim: 0.1935 - val_critic_loss: -0.0038 - val_decoder_accuracy: 0.5745 - val_decoder_loss: 0.6826 - val_encoder_decoder_total_loss: 0.8435 - val_psnr: 8.1447 - val_realism_loss: 5.5430e-04 - val_rs_bpp: 0.7449 - val_similarity_loss: 0.1604 - val_ssim: 0.1682
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - critic_loss: -0.0046 - decoder_accuracy: 0.5770 - decoder_loss: 0.6779 - encoder_decoder_total_loss: 0.7697 - psnr: 10.6477 - realism_loss: -8.9108e-04 - rs_bpp: 0.7697 - similarity_loss: 0.0927 - ssim: 0.4267 - val_critic_loss: -0.0104 - val_decoder_accuracy: 0.6420 - val_decoder_loss: 0.6441 - val_encoder_decoder_total_loss: 0.6958 - val_psnr: 12.6558 - val_realism_loss: -0.0037 - val_rs_bpp: 1.4196 - val_similarity_loss: 0.0554 - val_ssim: 0.4649
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - critic_loss: -0.0128 - decoder_accuracy: 0.6648 - decoder_loss: 0.6148 - encoder_decoder_total_loss: 0.6731 - psnr: 12.1811 - realism_loss: -0.0073 - rs_bpp: 1.6479 - similarity_loss: 0.0656 - ssim: 0.4303 - val_critic_loss: -0.0179 - val_decoder_accuracy: 0.7130 - val_decoder_loss: 0.5690 - val_encoder_decoder_total_loss: 0.5921 - val_psnr: 13.8866 - val_realism_loss: -0.0193 - val_rs_bpp: 2.1299 - val_similarity_loss: 0.0425 - val_ssim: 0.5325
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - critic_loss: -0.0240 - decoder_accuracy: 0.7351 - decoder_loss: 0.5321 - encoder_decoder_total_loss: 0.5688 - psnr: 12.6425 - realism_loss: -0.0221 - rs_bpp: 2.3505 - similarity_loss: 0.0588 - ssim: 0.4221 - val_critic_loss: -0.0306 - val_decoder_accuracy: 0.7612 - val_decoder_loss: 0.4999 - val_encoder_decoder_total_loss: 0.5109 - val_psnr: 13.7050 - val_realism_loss: -0.0347 - val_rs_bpp: 2.6119 - val_similarity_loss: 0.0457 - val_ssim: 0.4949
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - critic_loss: -0.0353 - decoder_accuracy: 0.7800 - decoder_loss: 0.4647 - encoder_decoder_total_loss: 0.4969 - psnr: 12.0992 - realism_loss: -0.0345 - rs_bpp: 2.7998 - similarity_loss: 0.0667 - ssim: 0.3766 - val_critic_loss: -0.0382 - val_decoder_accuracy: 0.7994 - val_decoder_loss: 0.4337 - val_encoder_decoder_total_loss: 0.4391 - val_psnr: 13.4691 - val_realism_loss: -0.0436 - val_rs_bpp: 2.9942 - val_similarity_loss: 0.0490 - val_ssim: 0.4468
