# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_dense_model,
  steganogan_decoder_dense_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-23 21:28:26.041846: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 4
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_dense.keras'
LOGS_PATH = f'../../logs/dense/{MESSAGE_DEPTH}/steganoGAN.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/dense/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - critic_loss: -7.8219e-04 - decoder_accuracy: 0.5650 - decoder_loss: 0.7311 - encoder_decoder_total_loss: 0.9468 - psnr: 7.6560 - realism_loss: 5.4491e-04 - rs_bpp: 0.5198 - similarity_loss: 0.2151 - ssim: 0.2902 - val_critic_loss: -0.0037 - val_decoder_accuracy: 0.7151 - val_decoder_loss: 0.6114 - val_encoder_decoder_total_loss: 0.6764 - val_psnr: 11.8237 - val_realism_loss: -0.0014 - val_rs_bpp: 1.7206 - val_similarity_loss: 0.0664 - val_ssim: 0.4288
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - critic_loss: -0.0066 - decoder_accuracy: 0.7686 - decoder_loss: 0.4891 - encoder_decoder_total_loss: 0.5564 - psnr: 11.6260 - realism_loss: -0.0029 - rs_bpp: 2.1489 - similarity_loss: 0.0702 - ssim: 0.4026 - val_critic_loss: -0.0154 - val_decoder_accuracy: 0.8374 - val_decoder_loss: 0.4143 - val_encoder_decoder_total_loss: 0.4806 - val_psnr: 11.0987 - val_realism_loss: -0.0133 - val_rs_bpp: 2.6988 - val_similarity_loss: 0.0797 - val_ssim: 0.3421
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 264s 1s/step - critic_loss: -0.0206 - decoder_accuracy: 0.8605 - decoder_loss: 0.3307 - encoder_decoder_total_loss: 0.3894 - psnr: 11.1769 - realism_loss: -0.0201 - rs_bpp: 2.8843 - similarity_loss: 0.0789 - ssim: 0.3142 - val_critic_loss: -0.0350 - val_decoder_accuracy: 0.8862 - val_decoder_loss: 0.2872 - val_encoder_decoder_total_loss: 0.3397 - val_psnr: 11.0289 - val_realism_loss: -0.0302 - val_rs_bpp: 3.0897 - val_similarity_loss: 0.0828 - val_ssim: 0.2848
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 268s 1s/step - critic_loss: -0.0388 - decoder_accuracy: 0.8893 - decoder_loss: 0.2689 - encoder_decoder_total_loss: 0.3118 - psnr: 11.3651 - realism_loss: -0.0334 - rs_bpp: 3.1143 - similarity_loss: 0.0763 - ssim: 0.2913 - val_critic_loss: -0.0479 - val_decoder_accuracy: 0.8998 - val_decoder_loss: 0.2484 - val_encoder_decoder_total_loss: 0.2915 - val_psnr: 11.3235 - val_realism_loss: -0.0348 - val_rs_bpp: 3.1980 - val_similarity_loss: 0.0780 - val_ssim: 0.2842
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 272s 1s/step - critic_loss: -0.0516 - decoder_accuracy: 0.8995 - decoder_loss: 0.2456 - encoder_decoder_total_loss: 0.2840 - psnr: 11.5153 - realism_loss: -0.0358 - rs_bpp: 3.1957 - similarity_loss: 0.0742 - ssim: 0.2860 - val_critic_loss: -0.0581 - val_decoder_accuracy: 0.9063 - val_decoder_loss: 0.2318 - val_encoder_decoder_total_loss: 0.2695 - val_psnr: 11.6181 - val_realism_loss: -0.0354 - val_rs_bpp: 3.2503 - val_similarity_loss: 0.0732 - val_ssim: 0.2937
