# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_dense_model,
  steganogan_decoder_dense_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-23 09:48:56.854935: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 2
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_dense.keras'
LOGS_PATH = f'../../logs/dense/{MESSAGE_DEPTH}/steganoGAN.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/dense/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 281s 1s/step - critic_loss: -8.7393e-04 - decoder_accuracy: 0.5971 - decoder_loss: 0.6934 - encoder_decoder_total_loss: 0.8433 - psnr: 8.7775 - realism_loss: -4.2185e-04 - rs_bpp: 0.3883 - similarity_loss: 0.1503 - ssim: 0.3547 - val_critic_loss: -0.0062 - val_decoder_accuracy: 0.9108 - val_decoder_loss: 0.4767 - val_encoder_decoder_total_loss: 0.5581 - val_psnr: 10.9054 - val_realism_loss: -3.1912e-04 - val_rs_bpp: 1.6431 - val_similarity_loss: 0.0817 - val_ssim: 0.3916
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 262s 1s/step - critic_loss: -0.0102 - decoder_accuracy: 0.9446 - decoder_loss: 0.1812 - encoder_decoder_total_loss: 0.2669 - psnr: 10.6569 - realism_loss: -0.0023 - rs_bpp: 1.7783 - similarity_loss: 0.0880 - ssim: 0.3226 - val_critic_loss: -0.0278 - val_decoder_accuracy: 0.9809 - val_decoder_loss: 0.1452 - val_encoder_decoder_total_loss: 0.2017 - val_psnr: 11.3973 - val_realism_loss: -0.0177 - val_rs_bpp: 1.9235 - val_similarity_loss: 0.0742 - val_ssim: 0.3677
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - critic_loss: -0.0321 - decoder_accuracy: 0.9823 - decoder_loss: 0.0696 - encoder_decoder_total_loss: 0.1114 - psnr: 11.8869 - realism_loss: -0.0250 - rs_bpp: 1.9291 - similarity_loss: 0.0668 - ssim: 0.3797 - val_critic_loss: -0.0417 - val_decoder_accuracy: 0.9867 - val_decoder_loss: 0.0600 - val_encoder_decoder_total_loss: 0.0871 - val_psnr: 12.2099 - val_realism_loss: -0.0348 - val_rs_bpp: 1.9466 - val_similarity_loss: 0.0619 - val_ssim: 0.4147
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 280s 1s/step - critic_loss: -0.0438 - decoder_accuracy: 0.9874 - decoder_loss: 0.0473 - encoder_decoder_total_loss: 0.0619 - psnr: 12.9862 - realism_loss: -0.0372 - rs_bpp: 1.9496 - similarity_loss: 0.0519 - ssim: 0.4376 - val_critic_loss: -0.0512 - val_decoder_accuracy: 0.9903 - val_decoder_loss: 0.0400 - val_encoder_decoder_total_loss: 0.0511 - val_psnr: 13.4871 - val_realism_loss: -0.0357 - val_rs_bpp: 1.9613 - val_similarity_loss: 0.0468 - val_ssim: 0.4825
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 277s 1s/step - critic_loss: -0.0546 - decoder_accuracy: 0.9887 - decoder_loss: 0.0397 - encoder_decoder_total_loss: 0.0480 - psnr: 13.7812 - realism_loss: -0.0350 - rs_bpp: 1.9549 - similarity_loss: 0.0433 - ssim: 0.4850 - val_critic_loss: -0.0613 - val_decoder_accuracy: 0.9904 - val_decoder_loss: 0.0372 - val_encoder_decoder_total_loss: 0.0458 - val_psnr: 14.3745 - val_realism_loss: -0.0297 - val_rs_bpp: 1.9614 - val_similarity_loss: 0.0383 - val_ssim: 0.5316
