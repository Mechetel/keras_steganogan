# %% [markdown]
# # SteganoGAN in Keras
# This notebook contains code attempting to reimplement SteganoGAN in Keras, for the purpose of better understanding (and scrutinizing) it.
#
# *Based on https://github.com/DAI-Lab/SteganoGAN/tree/master/steganogan*

# %% [markdown]
# ### Modules

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import sys
sys.path.append("../..")
sys.path.append("../../..")

import tensorflow as tf
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import CSVLogger
from callbacks import Checkpoint, SaveImages

from models import (
  steganogan_encoder_dense_model,
  steganogan_decoder_dense_model,
  steganogan_critic_model
)

from dataset_utils import normalize_img, create_message_dataset
from keras_steganogan import KerasSteganoGAN
# Out:
# 2024-09-23 21:04:33.603553: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Constants

# %%
# Image dimensions
IMAGE_HEIGHT = 128
IMAGE_WIDTH = 128
IMAGE_CHANNELS = 3

IMAGE_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)
MESSAGE_DEPTH = 3
BATCH_SIZE = 4
MODEL_PATH = f'../../pretrained_models/{MESSAGE_DEPTH}/steganoGAN_dense.keras'
LOGS_PATH = f'../../logs/dense/{MESSAGE_DEPTH}/steganoGAN.csv'
CALLBACK_IMAGES_PATH = '../../../images/callback'
CALLBACK_IMAGES_OUTPUT_PATH = f'../../epoch_images/dense/{MESSAGE_DEPTH}'

# %% [markdown]
# ----

# %% [markdown]
# ### Build model for future train

# %%
encoder = steganogan_encoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
decoder = steganogan_decoder_dense_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS, MESSAGE_DEPTH)
critic = steganogan_critic_model(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)

steganoGAN = KerasSteganoGAN(
  encoder=encoder,
  decoder=decoder,
  critic=critic,
  image_shape=IMAGE_SHAPE,
  data_depth=MESSAGE_DEPTH,
  model_path=MODEL_PATH
)

steganoGAN.compile(
  encoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  decoder_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  critic_optimizer = Adam(learning_rate=1e-4, beta_1=0.5),
  loss_fn = BinaryCrossentropy(from_logits=False)
)

#steganoGAN.models_summary()
#steganoGAN.summary()

# %% [markdown]
# ### Download div2k dataset and complete it with random message dataset of {0, 1}

# %%
train_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/train'
val_dir = '/Users/dmitryhoma/Projects/phd_dissertation/state_2/SteganoGAN/research/data/div2k/val'

train_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

val_image_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir, 
    label_mode=None, 
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    seed=123,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    shuffle=True
)

train_image_ds = train_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
val_image_ds = val_image_ds.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)

train_message_ds = create_message_dataset(BATCH_SIZE, len(train_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)
val_message_ds = create_message_dataset(BATCH_SIZE, len(val_image_ds), IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)

train_ds = tf.data.Dataset.zip((train_image_ds, train_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = tf.data.Dataset.zip((val_image_ds, val_message_ds)).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 800 files.
# Found 100 files.

# %%
steganoGAN.build([(1, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS), (1, IMAGE_HEIGHT, IMAGE_WIDTH, MESSAGE_DEPTH)])
steganoGAN.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=[
  SaveImages(MESSAGE_DEPTH, IMAGE_SHAPE, CALLBACK_IMAGES_PATH, CALLBACK_IMAGES_OUTPUT_PATH),
  Checkpoint(MODEL_PATH),
  CSVLogger(LOGS_PATH)
])
# Out:
# Epoch 1/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - critic_loss: -8.3092e-04 - decoder_accuracy: 0.5738 - decoder_loss: 0.7223 - encoder_decoder_total_loss: 0.9235 - psnr: 7.8027 - realism_loss: -3.6927e-05 - rs_bpp: 0.4427 - similarity_loss: 0.2013 - ssim: 0.2927 - val_critic_loss: -0.0039 - val_decoder_accuracy: 0.7603 - val_decoder_loss: 0.5752 - val_encoder_decoder_total_loss: 0.6448 - val_psnr: 11.5437 - val_realism_loss: -8.3053e-04 - val_rs_bpp: 1.5617 - val_similarity_loss: 0.0704 - val_ssim: 0.4136
# Epoch 2/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - critic_loss: -0.0075 - decoder_accuracy: 0.8638 - decoder_loss: 0.3411 - encoder_decoder_total_loss: 0.4270 - psnr: 10.6808 - realism_loss: -0.0018 - rs_bpp: 2.1828 - similarity_loss: 0.0876 - ssim: 0.3149 - val_critic_loss: -0.0203 - val_decoder_accuracy: 0.9399 - val_decoder_loss: 0.2486 - val_encoder_decoder_total_loss: 0.3337 - val_psnr: 10.2522 - val_realism_loss: -0.0114 - val_rs_bpp: 2.6393 - val_similarity_loss: 0.0964 - val_ssim: 0.2854
# Epoch 3/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - critic_loss: -0.0259 - decoder_accuracy: 0.9520 - decoder_loss: 0.1517 - encoder_decoder_total_loss: 0.2201 - psnr: 10.7161 - realism_loss: -0.0198 - rs_bpp: 2.7118 - similarity_loss: 0.0881 - ssim: 0.2693 - val_critic_loss: -0.0376 - val_decoder_accuracy: 0.9703 - val_decoder_loss: 0.1175 - val_encoder_decoder_total_loss: 0.1674 - val_psnr: 10.8669 - val_realism_loss: -0.0356 - val_rs_bpp: 2.8218 - val_similarity_loss: 0.0856 - val_ssim: 0.2692
# Epoch 4/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 270s 1s/step - critic_loss: -0.0429 - decoder_accuracy: 0.9713 - decoder_loss: 0.0961 - encoder_decoder_total_loss: 0.1376 - psnr: 11.2494 - realism_loss: -0.0372 - rs_bpp: 2.8280 - similarity_loss: 0.0787 - ssim: 0.2780 - val_critic_loss: -0.0586 - val_decoder_accuracy: 0.9793 - val_decoder_loss: 0.0773 - val_encoder_decoder_total_loss: 0.1238 - val_psnr: 11.3532 - val_realism_loss: -0.0311 - val_rs_bpp: 2.8761 - val_similarity_loss: 0.0776 - val_ssim: 0.2837
# Epoch 5/5
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - critic_loss: -0.0622 - decoder_accuracy: 0.9775 - decoder_loss: 0.0749 - encoder_decoder_total_loss: 0.1171 - psnr: 11.5417 - realism_loss: -0.0317 - rs_bpp: 2.8648 - similarity_loss: 0.0739 - ssim: 0.2880 - val_critic_loss: -0.0667 - val_decoder_accuracy: 0.9812 - val_decoder_loss: 0.0668 - val_encoder_decoder_total_loss: 0.1080 - val_psnr: 11.7565 - val_realism_loss: -0.0298 - val_rs_bpp: 2.8874 - val_similarity_loss: 0.0710 - val_ssim: 0.3087
